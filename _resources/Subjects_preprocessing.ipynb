# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import spacy
import nltk
from rake_nltk import Rake

# %matplotlib inline

# %%
subjects = pd.read_json('subjects.syllabus.json')

# %%
subjects = subjects.drop('_id', axis=1)

# %%
subjects
# Out:
#    title                                           syllabus
# 0   chem  [Chemistry in Day- Today Life: Overview of rol...
# 1     cn  [Fundamentals of networking and data communica...
# 2   DBMS  [DBMS Vs File Systems, Database System Archite...
# 3   dmgt  [Set Theory: Sets, Combinations of sets, Venn ...
# 4    FDS  [Introduction to Data Structures: Data, Data O...
# 5   mech  [Introduction and Operations with Forces: Intr...
# 6    oop  [Introduction to Object Oriented Programming (...
# 7     OS  [Operating System objectives and its evolution...
# 8   aies  [Introduction to Artificial Intelligence and S...
# 9    bdt  [Fundamentals and Basics of Big Data:Introduct...
# 10    de  [Introduction to Data Engineering, Defining Da...
# 11   fsd  [html, css, js, bootstrap, xml, dom, jquery, a...
# 12   ICS  [Foundations of Information Security, Informat...
# 13  ddca  [Number Systems and Digital Arithmetic: Introd...
# 14   mmc  [Pentium features, Pentium superscalar archite...
# 15   ads  [Collision resolution strategies- open address...
# 16   daa  [Efficiency- Analysis framework, asymptotic no...
# 17    ps  [Measure of Skewness and Kurtosis based on mom...
# 18  sepm  [Software engineering process, What is Softwar...

# %% [markdown]
# ## Convert list to concat strings

# %%
" ".join(subjects.syllabus[0])
# Out:
# 'Chemistry in Day- Today Life: Overview of role of Chemistry in our daily life Water Technology and Phase Rule: Importance of potable water Specifications for drinking water Water analysis â€“ hardness alkalinity chloride and dissolved oxygen Ill effects of hard water \nin boilers Boiler feed water treatments- Zeolite and Ion exchange numerical Desalination techniques reverse osmosis and electro-dialysis Phase rule -one component system- Water Applications and limitations of Phase rule Advanced Electrochemistry-Nernst equation Electrodes Primary and secondary batteries Fuel Cells â€“ Definition advantages and limitations Types of Fuel cells-AFC SOFC PEMFC and PAFC supercapacitors Corrosion Science: Types of corrosion- Dry corrosion- mechanism Pilling-Bedworth rule Wet corrosion - mechanism factors influencing corrosion Types of corrosion-stress corrosion pitting corrosion crevice corrosion intergranular corrosion water corrosion Methods of corrosion control- Cathodic protection and anodic protective coatings- metallic coatings and nonmetallic coatings powder coating plasma spraying method electrostatic spraying Fuels and Combustion: Classification of chemical fuels calorific value Bomb Calorimeter Solid fuel - Coal - proximate and ultimate analysis Liquid fuels - Petroleum - composition and refining Petrol Diesel Jet fuels and biodiesel quality parameters Gaseous fuels: natural gas water gas liquefied petroleum gas hydrogen as future fuel Combustion: chemical reactions calculations of air required Polymer Chemistry: Polymers in day-to-day life functionality of monomers polymerization mechanism crystallinity in polymers thermal transitions in polymers-Tm and Tg thermoplastic and thermosetting polymers Techniques of addition polymerization Synthesis of certain polymers and their applications - epoxy resins acrylonitrile-butadiene-styrene polypropylene Compounding of plastics Specialty polymers- Conducting Polymers Smart polymers Bio-based and biodegradable polymers Recycling of polymers Green Chemistry: Green Chemistry - Definition goals twelve principles need and industrial applications Efficiency parameters green solvents solid acid catalysts traditional and green pathways of synthesis of ibuprofen polyurethane and green hydrogenation methods Absorption Spectroscopy â€“ Principle instrumentation and applications of UV-Visible spectroscopy-Woodward-Fieser rules with examples '

# %%
subjects.syllabus = subjects.syllabus.apply(lambda x: " ".join(x))

# %% [markdown]
# ## Normalize to lowercase

# %%
subjects.syllabus = subjects.syllabus.apply(lambda x: x.lower())

# %%
subjects.title = subjects.title.apply(lambda x: x.lower())

# %%
subjects
# Out:
#    title                                           syllabus
# 0   chem  chemistry in day- today life: overview of role...
# 1     cn  fundamentals of networking and data communicat...
# 2   dbms  dbms vs file systems database system architect...
# 3   dmgt  set theory: sets combinations of sets venn dia...
# 4    fds  introduction to data structures: data data obj...
# 5   mech  introduction and operations with forces: intro...
# 6    oop  introduction to object oriented programming (o...
# 7     os  operating system objectives and its evolution ...
# 8   aies  introduction to artificial intelligence and se...
# 9    bdt  fundamentals and basics of big data:introducti...
# 10    de  introduction to data engineering defining data...
# 11   fsd  html css js bootstrap xml dom jquery ajax php ...
# 12   ics  foundations of information security informatio...
# 13  ddca  number systems and digital arithmetic: introdu...
# 14   mmc  pentium features pentium superscalar architect...
# 15   ads  collision resolution strategies- open addressi...
# 16   daa  efficiency- analysis framework asymptotic nota...
# 17    ps  measure of skewness and kurtosis based on mome...
# 18  sepm  software engineering process what is software ...

# %% [markdown]
# ## Perform POS Tagging

# %%
nlp = spacy.load('en_core_web_sm')

# %%
chem_doc = nlp(subjects.syllabus[0])

# %%
chem_doc
# Out:
# chemistry in day- today life: overview of role of chemistry in our daily life water technology and phase rule: importance of potable water specifications for drinking water water analysis â€“ hardness alkalinity chloride and dissolved oxygen ill effects of hard water
# in boilers boiler feed water treatments- zeolite and ion exchange numerical desalination techniques reverse osmosis and electro-dialysis phase rule -one component system- water applications and limitations of phase rule advanced electrochemistry-nernst equation electrodes primary and secondary batteries fuel cells â€“ definition advantages and limitations types of fuel cells-afc sofc pemfc and pafc supercapacitors corrosion science: types of corrosion- dry corrosion- mechanism pilling-bedworth rule wet corrosion - mechanism factors influencing corrosion types of corrosion-stress corrosion pitting corrosion crevice corrosion intergranular corrosion water corrosion methods of corrosion control- cathodic protection and anodic protective coatings- metallic coatings and nonmetallic coatings powder coating plasma spraying method electrostatic spraying fuels and combustion: classification of chemical fuels calorific value bomb calorimeter solid fuel - coal - proximate and ultimate analysis liquid fuels - petroleum - composition and refining petrol diesel jet fuels and biodiesel quality parameters gaseous fuels: natural gas water gas liquefied petroleum gas hydrogen as future fuel combustion: chemical reactions calculations of air required polymer chemistry: polymers in day-to-day life functionality of monomers polymerization mechanism crystallinity in polymers thermal transitions in polymers-tm and tg thermoplastic and thermosetting polymers techniques of addition polymerization synthesis of certain polymers and their applications - epoxy resins acrylonitrile-butadiene-styrene polypropylene compounding of plastics specialty polymers- conducting polymers smart polymers bio-based and biodegradable polymers recycling of polymers green chemistry: green chemistry - definition goals twelve principles need and industrial applications efficiency parameters green solvents solid acid catalysts traditional and green pathways of synthesis of ibuprofen polyurethane and green hydrogenation methods absorption spectroscopy â€“ principle instrumentation and applications of uv-visible spectroscopy-woodward-fieser rules with examples

# %%
chem_doc[0].pos_
# Out:
# 'NOUN'

# %%
chem_doc[1].pos_
# Out:
# 'ADP'

# %% [markdown]
# - NOUN
# - PROPN
# - ADJ
# - VERB

# %%
unique_pos = set()
for word in chem_doc:
    unique_pos.add(word.pos_)

# %%
unique_pos
# Out:
# {'ADJ',
#  'ADP',
#  'CCONJ',
#  'NOUN',
#  'NUM',
#  'PRON',
#  'PROPN',
#  'PUNCT',
#  'SPACE',
#  'VERB',
#  'X'}

# %%
chem_doc
# Out:
# chemistry in day- today life: overview of role of chemistry in our daily life water technology and phase rule: importance of potable water specifications for drinking water water analysis â€“ hardness alkalinity chloride and dissolved oxygen ill effects of hard water
# in boilers boiler feed water treatments- zeolite and ion exchange numerical desalination techniques reverse osmosis and electro-dialysis phase rule -one component system- water applications and limitations of phase rule advanced electrochemistry-nernst equation electrodes primary and secondary batteries fuel cells â€“ definition advantages and limitations types of fuel cells-afc sofc pemfc and pafc supercapacitors corrosion science: types of corrosion- dry corrosion- mechanism pilling-bedworth rule wet corrosion - mechanism factors influencing corrosion types of corrosion-stress corrosion pitting corrosion crevice corrosion intergranular corrosion water corrosion methods of corrosion control- cathodic protection and anodic protective coatings- metallic coatings and nonmetallic coatings powder coating plasma spraying method electrostatic spraying fuels and combustion: classification of chemical fuels calorific value bomb calorimeter solid fuel - coal - proximate and ultimate analysis liquid fuels - petroleum - composition and refining petrol diesel jet fuels and biodiesel quality parameters gaseous fuels: natural gas water gas liquefied petroleum gas hydrogen as future fuel combustion: chemical reactions calculations of air required polymer chemistry: polymers in day-to-day life functionality of monomers polymerization mechanism crystallinity in polymers thermal transitions in polymers-tm and tg thermoplastic and thermosetting polymers techniques of addition polymerization synthesis of certain polymers and their applications - epoxy resins acrylonitrile-butadiene-styrene polypropylene compounding of plastics specialty polymers- conducting polymers smart polymers bio-based and biodegradable polymers recycling of polymers green chemistry: green chemistry - definition goals twelve principles need and industrial applications efficiency parameters green solvents solid acid catalysts traditional and green pathways of synthesis of ibuprofen polyurethane and green hydrogenation methods absorption spectroscopy â€“ principle instrumentation and applications of uv-visible spectroscopy-woodward-fieser rules with examples

# %%
for word in chem_doc:
    if word.pos_ == 'PRON':
        print(word)
# Out:
# our
# their

# %%
useful_pos = ['NOUN', 'PROPN', 'ADJ', 'VERB']

# %%
pos_tagged = [word for word in chem_doc if word.pos_ in useful_pos]

# %%
pos_tagged[0].orth_
# Out:
# 'chemistry'

# %%
pos_tagged_str = []
for each in pos_tagged:
    pos_tagged_str.append(each.orth_)

# %%
chem_text = " ".join(pos_tagged_str)

# %%
chem_text
# Out:
# 'chemistry day- today life overview role chemistry daily life water technology phase rule importance potable water specifications drinking water water analysis hardness alkalinity chloride dissolved oxygen ill effects hard water boilers boiler feed water treatments- zeolite ion exchange numerical desalination techniques reverse osmosis electro dialysis phase rule component system- water applications limitations phase rule advanced electrochemistry nernst equation electrodes primary secondary batteries fuel cells definition advantages limitations types fuel cells afc sofc pemfc pafc supercapacitors corrosion science types dry corrosion- mechanism pilling bedworth rule wet corrosion mechanism factors influencing corrosion types corrosion stress corrosion pitting corrosion crevice corrosion intergranular corrosion water corrosion methods corrosion control- cathodic protection anodic protective coatings- metallic coatings nonmetallic coatings powder coating plasma spraying method electrostatic spraying fuels combustion classification chemical fuels calorific value bomb calorimeter solid fuel coal proximate ultimate analysis liquid fuels petroleum composition refining petrol diesel jet fuels biodiesel quality parameters gaseous fuels natural gas water gas liquefied petroleum gas hydrogen future fuel combustion chemical reactions calculations air required polymer chemistry polymers day day life functionality monomers polymerization mechanism crystallinity polymers thermal transitions polymers tm tg thermoplastic thermosetting polymers techniques addition polymerization synthesis certain polymers applications epoxy resins acrylonitrile butadiene styrene polypropylene compounding plastics specialty polymers- conducting polymers smart polymers bio based biodegradable polymers recycling polymers green chemistry green chemistry definition goals principles need industrial applications efficiency parameters green solvents solid acid catalysts traditional green pathways synthesis ibuprofen polyurethane green hydrogenation methods absorption spectroscopy principle instrumentation applications uv visible spectroscopy woodward fieser rules examples'

# %% [markdown]
# ## Lemmetization

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
lemmatized_words = [lemmatizer.lemmatize(word) for word in pos_tagged_str]

# %% [markdown]
# ### Remove duplicates

# %%
lemmatized_words = set(lemmatized_words)

# %%
chem_text = " ".join(lemmatized_words)

# %%
chem_text
# Out:
# 'diesel solid epoxy thermosetting acrylonitrile day- alkalinity smart certain uv calorific limitation thermoplastic wet biodegradable classification butadiene definition potable nernst overview powder advantage ultimate method specialty hydrogenation visible spraying electrochemistry day cell pemfc recycling crevice transition system- dry pathway gas ion catalyst quality styrene specification addition resin battery ill reaction oxygen natural crystallinity sofc compounding gaseous hard petroleum treatments- equation boiler based solvent daily role electrode functionality technique absorption coatings- tg biodiesel application traditional analysis science influencing principle petrol liquefied chemical life metallic value primary composition required afc refining importance intergranular pitting chemistry coating dialysis cathodic polypropylene plastic rule nonmetallic hydrogen bedworth coal dissolved combustion numerical chloride reverse bio mechanism today monomer protective conducting jet air goal ibuprofen fieser corrosion liquid factor anodic calorimeter polymers- zeolite protection woodward proximate pafc green electro tm feed drinking phase supercapacitors type need component polymer osmosis effect control- plasma future fuel advanced efficiency calculation hardness pilling polymerization thermal water secondary synthesis spectroscopy industrial stress polyurethane technology bomb parameter acid instrumentation electrostatic corrosion- desalination example exchange'

# %% [markdown]
# ## Keyword Extraction

# %%
rake = Rake(include_repeated_phrases=False)

# %%
rake.extract_keywords_from_text(chem_text)

# %%
keywords = rake.get_ranked_phrases()

# %%
empty = ""
for keyword in keywords:
    print(keyword, "\n")
    empty += keyword
# Out:
# tg biodiesel application traditional analysis science influencing principle petrol liquefied chemical life metallic value primary composition required afc refining importance intergranular pitting chemistry coating dialysis cathodic polypropylene plastic rule nonmetallic hydrogen bedworth coal dissolved combustion numerical chloride reverse bio mechanism today monomer protective conducting jet air goal ibuprofen fieser corrosion liquid factor anodic calorimeter polymers
#
# alkalinity smart certain uv calorific limitation thermoplastic wet biodegradable classification butadiene definition potable nernst overview powder advantage ultimate method specialty hydrogenation visible spraying electrochemistry day cell pemfc recycling crevice transition system
#
# plasma future fuel advanced efficiency calculation hardness pilling polymerization thermal water secondary synthesis spectroscopy industrial stress polyurethane technology bomb parameter acid instrumentation electrostatic corrosion
#
# dry pathway gas ion catalyst quality styrene specification addition resin battery ill reaction oxygen natural crystallinity sofc compounding gaseous hard petroleum treatments
#
# zeolite protection woodward proximate pafc green electro tm feed drinking phase supercapacitors type need component polymer osmosis effect control
#
# equation boiler based solvent daily role electrode functionality technique absorption coatings
#
# diesel solid epoxy thermosetting acrylonitrile day
#
# desalination example exchange

# %%
empty
# Out:
# 'tg biodiesel application traditional analysis science influencing principle petrol liquefied chemical life metallic value primary composition required afc refining importance intergranular pitting chemistry coating dialysis cathodic polypropylene plastic rule nonmetallic hydrogen bedworth coal dissolved combustion numerical chloride reverse bio mechanism today monomer protective conducting jet air goal ibuprofen fieser corrosion liquid factor anodic calorimeter polymersalkalinity smart certain uv calorific limitation thermoplastic wet biodegradable classification butadiene definition potable nernst overview powder advantage ultimate method specialty hydrogenation visible spraying electrochemistry day cell pemfc recycling crevice transition systemplasma future fuel advanced efficiency calculation hardness pilling polymerization thermal water secondary synthesis spectroscopy industrial stress polyurethane technology bomb parameter acid instrumentation electrostatic corrosiondry pathway gas ion catalyst quality styrene specification addition resin battery ill reaction oxygen natural crystallinity sofc compounding gaseous hard petroleum treatmentszeolite protection woodward proximate pafc green electro tm feed drinking phase supercapacitors type need component polymer osmosis effect controlequation boiler based solvent daily role electrode functionality technique absorption coatingsdiesel solid epoxy thermosetting acrylonitrile daydesalination example exchange'

# %% [markdown]
# ## Preprocess Syllabus

# %%
useful_pos = ['NOUN', 'PROPN', 'ADJ', 'VERB']
def preprocess_syllabus(syllabus):
    #print(syllabus)
    syllabus = "".join(syllabus)
    #print(syllabus)
    syllabus = syllabus.lower()
    doc = nlp(syllabus)
    tagged = [word for word in doc if word.pos_ in useful_pos]
    tagged_str = []
    for each in tagged:
        tagged_str.append(each.orth_)
    lemmatizer = WordNetLemmatizer()
    lemmatized_words = [lemmatizer.lemmatize(word) for word in tagged_str]
    lemmatized_words = set(lemmatized_words)
    subject_text = " ".join(lemmatized_words)
    #print(subject_text)
    rake = Rake(include_repeated_phrases=False)
    rake.extract_keywords_from_text(subject_text)
    keywords = rake.get_ranked_phrases()
    #print(keywords)
    final = ""
    for keyword in keywords:
        final += keyword
    return final

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sadam\.conda\envs\spark\lib\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sadam\.conda\envs\spark\lib\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer
lem = WordNetLemmatizer()

corpus = []
for i in range(0,len(subjects['syllabus'])):
    review = re.sub('[^a-zA-Z0-9]',' ', subjects['syllabus'][i])
    review = review.lower()
    review = review.split()

    review = [lem.lemmatize(word) for word in review if word not in stopwords.words('english') or word in ['not','never']]
    review = ' '.join(review)
    corpus.append(review)

# %%
subjects['processed_syllabus'] = pd.DataFrame(corpus)

# %%
subjects
# Out:
#    title                                           syllabus  \
# 0   chem  chemistry in day- today life: overview of role...
# 1     cn  fundamentals of networking and data communicat...
# 2   dbms  dbms vs file systems database system architect...
# 3   dmgt  set theory: sets combinations of sets venn dia...
# 4    fds  introduction to data structures: data data obj...
# 5   mech  introduction and operations with forces: intro...
# 6    oop  introduction to object oriented programming (o...
# 7     os  operating system objectives and its evolution ...
# 8   aies  introduction to artificial intelligence and se...
# 9    bdt  fundamentals and basics of big data:introducti...
# 10    de  introduction to data engineering defining data...
# 11   fsd  html css js bootstrap xml dom jquery ajax php ...
# 12   ics  foundations of information security informatio...
# 13  ddca  number systems and digital arithmetic: introdu...
# 14   mmc  pentium features pentium superscalar architect...
# 15   ads  collision resolution strategies- open addressi...
# 16   daa  efficiency- analysis framework asymptotic nota...
# 17    ps  measure of skewness and kurtosis based on mome...
# 18  sepm  software engineering process what is software ...
#
#                                    extracted_keywords  \
# 0   tg biodiesel application traditional analysis ...
# 1   domain ftp control snmp cyclic window digital ...
# 2   domain 3nf deleting control shadow failure par...
# 3   extended pigeonhole eulerian inverse shortest ...
# 4   case finding order major algorithm notation in...
# 5   k composition kinematics velocity applicable a...
# 6   ambiguity io algorithm introduction access var...
# 7   reference consumer fifo partitioning algorithm...
# 8   uncertain application mycin set machine minima...
# 9   modeling j ecos read analytics theorem circula...
# 10  qualitative modeling implementation discretiza...
# 11  node express php xml mern jquery react j ajax ...
# 12  administrative cia anonymizers control symmetr...
# 13  sop combinational computer key binary applicat...
# 14  stage task cache branch pipelining handling sf...
# 15  queue direct trie b traversal perfect dikjtras...
# 16  encoding direct recursive counter mathematical...
# 17  exponential testing poisson f statistic theore...
# 18  testing modeling verification user chain ssad ...
#
#                                    processed_syllabus
# 0   chemistry day today life overview role chemist...
# 1   fundamental networking data communication anal...
# 2   dbms v file system database system architectur...
# 3   set theory set combination set venn diagram fi...
# 4   introduction data structure data data object a...
# 5   introduction operation force introduction engi...
# 6   introduction object oriented programming oop i...
# 7   operating system objective evolution operating...
# 8   introduction artificial intelligence search st...
# 9   fundamental basic big data introduction big da...
# 10  introduction data engineering defining data en...
# 11  html cs j bootstrap xml dom jquery ajax php wo...
# 12  foundation information security information se...
# 13  number system digital arithmetic introduction ...
# 14  pentium feature pentium superscalar architectu...
# 15  collision resolution strategy open addressing ...
# 16  efficiency analysis framework asymptotic notat...
# 17  measure skewness kurtosis based moment moment ...
# 18  software engineering process software engineer...

# %%
subjects['extracted_keywords'][13]
# Out:
# 'sop combinational computer key binary application set machine cisc twisted hierarchy multiplication block cpu shift principle sequential k memory risc bit cascading signed data system subractor processor ripple 1â € bus po gate half sign full diagramcache decoder pipelining hardwired user parallel digital characteristic counter subtraction map algebra modulus programmed representation concept conversion look instruction flip fundamental structure study visible mode subtractor cell unsigned microregister addressing adder type von alu number implementing architecture element ia status minimization cycle using boolean hazard ™ harvard complement organization generator logic design synchronousunit division function ring flow organizationcircuit introduction neumann flop addition operationscase arithmetic systemmagnitude multiplexer cyclememorycontrol carry'

# %%
preprocess_syllabus(subjects['syllabus'][0])
# Out:
# 'tg biodiesel application traditional analysis science influencing principle petrol liquefied chemical life metallic value primary composition required afc refining importance intergranular pitting chemistry coating dialysis cathodic polypropylene plastic rule nonmetallic hydrogen bedworth coal dissolved combustion numerical chloride reverse bio mechanism today monomer protective conducting jet air goal ibuprofen fieser corrosion liquid factor anodic calorimeter polymersalkalinity smart certain uv calorific limitation thermoplastic wet biodegradable classification butadiene definition potable nernst overview powder advantage ultimate method specialty hydrogenation visible spraying electrochemistry day cell pemfc recycling crevice transition systemplasma future fuel advanced efficiency calculation hardness pilling polymerization thermal water secondary synthesis spectroscopy industrial stress polyurethane technology bomb parameter acid instrumentation electrostatic corrosiondry pathway gas ion catalyst quality styrene specification addition resin battery ill reaction oxygen natural crystallinity sofc compounding gaseous hard petroleum treatmentszeolite protection woodward proximate pafc green electro tm feed drinking phase supercapacitors type need component polymer osmosis effect controlequation boiler based solvent daily role electrode functionality technique absorption coatingsdiesel solid epoxy thermosetting acrylonitrile daydesalination example exchange'

# %%
subjects['extracted_keywords'] = subjects['syllabus'].apply(preprocess_syllabus)

# %%
subjects
# Out:
#    title                                           syllabus  \
# 0   chem  chemistry in day- today life: overview of role...
# 1     cn  fundamentals of networking and data communicat...
# 2   dbms  dbms vs file systems database system architect...
# 3   dmgt  set theory: sets combinations of sets venn dia...
# 4    fds  introduction to data structures: data data obj...
# 5   mech  introduction and operations with forces: intro...
# 6    oop  introduction to object oriented programming (o...
# 7     os  operating system objectives and its evolution ...
# 8   aies  introduction to artificial intelligence and se...
# 9    bdt  fundamentals and basics of big data:introducti...
# 10    de  introduction to data engineering defining data...
# 11   fsd  html css js bootstrap xml dom jquery ajax php ...
# 12   ics  foundations of information security informatio...
# 13  ddca  number systems and digital arithmetic: introdu...
# 14   mmc  pentium features pentium superscalar architect...
# 15   ads  collision resolution strategies- open addressi...
# 16   daa  efficiency- analysis framework asymptotic nota...
# 17    ps  measure of skewness and kurtosis based on mome...
# 18  sepm  software engineering process what is software ...
#
#                                    extracted_keywords
# 0   tg biodiesel application traditional analysis ...
# 1   domain ftp control snmp cyclic window digital ...
# 2   domain 3nf deleting control shadow failure par...
# 3   extended pigeonhole eulerian inverse shortest ...
# 4   case finding order major algorithm notation in...
# 5   k composition kinematics velocity applicable a...
# 6   ambiguity io algorithm introduction access var...
# 7   reference consumer fifo partitioning algorithm...
# 8   uncertain application mycin set machine minima...
# 9   modeling j ecos read analytics theorem circula...
# 10  qualitative modeling implementation discretiza...
# 11  node express php xml mern jquery react j ajax ...
# 12  administrative cia anonymizers control symmetr...
# 13  sop combinational computer key binary applicat...
# 14  stage task cache branch pipelining handling sf...
# 15  queue direct trie b traversal perfect dikjtras...
# 16  encoding direct recursive counter mathematical...
# 17  exponential testing poisson f statistic theore...
# 18  testing modeling verification user chain ssad ...

# %%
subjects.to_json('preprocessed_subjects.json')

# %%
subjects
# Out:
#    title                                           syllabus  \
# 0   chem  chemistry in day- today life: overview of role...
# 1     cn  fundamentals of networking and data communicat...
# 2   dbms  dbms vs file systems database system architect...
# 3   dmgt  set theory: sets combinations of sets venn dia...
# 4    fds  introduction to data structures: data data obj...
# 5   mech  introduction and operations with forces: intro...
# 6    oop  introduction to object oriented programming (o...
# 7     os  operating system objectives and its evolution ...
# 8   aies  introduction to artificial intelligence and se...
# 9    bdt  fundamentals and basics of big data:introducti...
# 10    de  introduction to data engineering defining data...
# 11   fsd  html css js bootstrap xml dom jquery ajax php ...
# 12   ics  foundations of information security informatio...
# 13  ddca  number systems and digital arithmetic: introdu...
# 14   mmc  pentium features pentium superscalar architect...
# 15   ads  collision resolution strategies- open addressi...
# 16   daa  efficiency- analysis framework asymptotic nota...
# 17    ps  measure of skewness and kurtosis based on mome...
# 18  sepm  software engineering process what is software ...
#
#                                    extracted_keywords
# 0   tg biodiesel application traditional analysis ...
# 1   domain ftp control snmp cyclic window digital ...
# 2   domain 3nf deleting control shadow failure par...
# 3   extended pigeonhole eulerian inverse shortest ...
# 4   case finding order major algorithm notation in...
# 5   k composition kinematics velocity applicable a...
# 6   ambiguity io algorithm introduction access var...
# 7   reference consumer fifo partitioning algorithm...
# 8   uncertain application mycin set machine minima...
# 9   modeling j ecos read analytics theorem circula...
# 10  qualitative modeling implementation discretiza...
# 11  node express php xml mern jquery react j ajax ...
# 12  administrative cia anonymizers control symmetr...
# 13  sop combinational computer key binary applicat...
# 14  stage task cache branch pipelining handling sf...
# 15  queue direct trie b traversal perfect dikjtras...
# 16  encoding direct recursive counter mathematical...
# 17  exponential testing poisson f statistic theore...
# 18  testing modeling verification user chain ssad ...

# %%
subjects['extracted_keywords'][13]
# Out:
# 'sop combinational computer key binary application set machine cisc twisted hierarchy multiplication block cpu shift principle sequential k memory risc bit cascading signed data system subractor processor ripple 1â € bus po gate half sign full diagramcache decoder pipelining hardwired user parallel digital characteristic counter subtraction map algebra modulus programmed representation concept conversion look instruction flip fundamental structure study visible mode subtractor cell unsigned microregister addressing adder type von alu number implementing architecture element ia status minimization cycle using boolean hazard ™ harvard complement organization generator logic design synchronousunit division function ring flow organizationcircuit introduction neumann flop addition operationscase arithmetic systemmagnitude multiplexer cyclememorycontrol carry'

# %% [markdown]
# ## Model

# %%
subjects
# Out:
#    title                                           syllabus  \
# 0   chem  chemistry in day- today life: overview of role...
# 1     cn  fundamentals of networking and data communicat...
# 2   dbms  dbms vs file systems database system architect...
# 3   dmgt  set theory: sets combinations of sets venn dia...
# 4    fds  introduction to data structures: data data obj...
# 5   mech  introduction and operations with forces: intro...
# 6    oop  introduction to object oriented programming (o...
# 7     os  operating system objectives and its evolution ...
# 8   aies  introduction to artificial intelligence and se...
# 9    bdt  fundamentals and basics of big data:introducti...
# 10    de  introduction to data engineering defining data...
# 11   fsd  html css js bootstrap xml dom jquery ajax php ...
# 12   ics  foundations of information security informatio...
# 13  ddca  number systems and digital arithmetic: introdu...
# 14   mmc  pentium features pentium superscalar architect...
# 15   ads  collision resolution strategies- open addressi...
# 16   daa  efficiency- analysis framework asymptotic nota...
# 17    ps  measure of skewness and kurtosis based on mome...
# 18  sepm  software engineering process what is software ...
#
#                                    extracted_keywords  \
# 0   tg biodiesel application traditional analysis ...
# 1   domain ftp control snmp cyclic window digital ...
# 2   domain 3nf deleting control shadow failure par...
# 3   extended pigeonhole eulerian inverse shortest ...
# 4   case finding order major algorithm notation in...
# 5   k composition kinematics velocity applicable a...
# 6   ambiguity io algorithm introduction access var...
# 7   reference consumer fifo partitioning algorithm...
# 8   uncertain application mycin set machine minima...
# 9   modeling j ecos read analytics theorem circula...
# 10  qualitative modeling implementation discretiza...
# 11  node express php xml mern jquery react j ajax ...
# 12  administrative cia anonymizers control symmetr...
# 13  sop combinational computer key binary applicat...
# 14  stage task cache branch pipelining handling sf...
# 15  queue direct trie b traversal perfect dikjtras...
# 16  encoding direct recursive counter mathematical...
# 17  exponential testing poisson f statistic theore...
# 18  testing modeling verification user chain ssad ...
#
#                                    processed_syllabus
# 0   chemistry day today life overview role chemist...
# 1   fundamental networking data communication anal...
# 2   dbms v file system database system architectur...
# 3   set theory set combination set venn diagram fi...
# 4   introduction data structure data data object a...
# 5   introduction operation force introduction engi...
# 6   introduction object oriented programming oop i...
# 7   operating system objective evolution operating...
# 8   introduction artificial intelligence search st...
# 9   fundamental basic big data introduction big da...
# 10  introduction data engineering defining data en...
# 11  html cs j bootstrap xml dom jquery ajax php wo...
# 12  foundation information security information se...
# 13  number system digital arithmetic introduction ...
# 14  pentium feature pentium superscalar architectu...
# 15  collision resolution strategy open addressing ...
# 16  efficiency analysis framework asymptotic notat...
# 17  measure skewness kurtosis based moment moment ...
# 18  software engineering process software engineer...

# %%
subjects['extracted_keywords'][11]
# Out:
# 'node express php xml mern jquery react j ajax bootstrap html dom wordpress mongo api cs'

# %%
X = subjects['processed_syllabus']
y = subjects['title']

# %%
yt = pd.read_json('yt_preprocessed.json')

# %%
yt['combo'][1]
# Out:
# 'Scrapy for Beginners - A Complete How To Example Web Scraping Project # DISCORD : Scrapy for Beginners! This python tutorial is aimed at people new to Scrapy. We cover crawling with a basic spider an create a complete tutorial project, including exporting to a JSON file. We scrape products from a online shop and get names and prices. Learn how to use the Scrapy shell to parse the data, and get text and "href" attributes from the HTML, as well as scraping multiple pages. This is a full how to from start to finish for your first Scrapy spider project, all in Python 3.code: # Proxies: # Patreon:  # The Scraper API I use: # Donate: # Hosting: Digital Ocean  - # Gear Used: DISCLAIMER This contains affiliate links. If you use these links to buy something we may earn a commission.'

# %%
yt
# Out:
#                                                  title  \
# 0    scrapy course – python web scraping for beginners
# 1    scrapy for beginners - a complete how to examp...
# 2    web scraping using scrapy | scrapy tutorial + ...
# 3             coding web crawler in python with scrapy
# 4                 python scrapy tutorial for beginners
# ..                                                 ...
# 595  standard template library (stl) in c++  | intr...
# 596  the c++ standard template library (stl) | c++ ...
# 597  stl templates in c++ - generic functions and c...
# 598  c++ templates: must for competitive programmin...
# 599  stl containers in c++ | sequence-vector | part...
#
#                                            description  \
# 0    The Scrapy Beginners Course will teach you eve...
# 1    # DISCORD (NEW): https://discord.gg/C4J2uckpbR...
# 2    Try Atlas: https://www.mongodb.com/cloud/atlas...
# 3    Today we learn how to build a professional web...
# 4    This Python Scrapy tutorial for beginners that...
# ..                                                 ...
# 595  Standard Template Library (STL) mainly compose...
# 596  The Standard Template Library (STL) is a set o...
# 597  In this video, we will learn about STL templat...
# 598  Download the best IDE for C, C# and C++: https...
# 599  Standard Template Library (STL) container- seq...
#
#                                                  combo   views  likes  \
# 0    serhiy first agustn website start extraction w...  436714   9886
# 1    hosting contains complete people multiple fini...  267940   5091
# 2    1 html read java javascript hr ]: complete scr...   46067   1012
# 3    code professional discord coding bible scrapin...  111544   2287
# 4    basic first find scope claim information glanc...     102      5
# ..                                                 ...     ...    ...
# 595  49 library video related c ++ iterators standa...   52898    644
# 596  best click javascript website oriented course ...  252714   9881
# 597  44 related start videoadd use text course powe...   16903    643
# 598  way hosting competitive science english comple...  364110  11354
# 599  vector priya sequencevectorplease c ++ related...   33608    341
#
#                                                    tag  \
# 0
# 1    scrapy python tutorial scrapy crawlspider scra...
# 2
# 3    python web crawler web crawling python web cra...
# 4    python scrapy tutorial for beginners python sc...
# ..                                                 ...
# 595  stl in c++ stl in c++ tutorial stl in c++ tuto...
# 596
# 597  c++ stl templates what are c++ templates c++ s...
# 598
# 599  C++ STL Container stl containers c++ sequence ...
#
#                                              url  duration     publisedAt
# 0    https://www.youtube.com/watch?v=mBoX_JCKZTE     16629  1682606288000
# 1    https://www.youtube.com/watch?v=s4jtkzHhLzY      1402  1607540409000
# 2    https://www.youtube.com/watch?v=GogxAQ2JP4A      3003  1687347004000
# 3    https://www.youtube.com/watch?v=m_3gjHGxIJc      2071  1669210212000
# 4    https://www.youtube.com/watch?v=41opDqo1im8      7140  1679465239000
# ..                                           ...       ...            ...
# 595  https://www.youtube.com/watch?v=fmKNmoZxiVU       424  1516724749000
# 596  https://www.youtube.com/watch?v=c9iREsYpayk       889  1599896391000
# 597  https://www.youtube.com/watch?v=-Svq5IYPWbc      1147  1709046132000
# 598  https://www.youtube.com/watch?v=kKJeekDKU30       796  1599489366000
# 599  https://www.youtube.com/watch?v=ZqnvVetaX5A       725  1516725658000
#
# [600 rows x 9 columns]

# %% [markdown]
# ### Vectorizer

# %% [markdown]
# 1. BOW
# 2. n-grams
# 3. Word2Vec

# %% [markdown]
# ### Classifier

# %% [markdown]
# 1. Naive Bayes
# 2. Random Forest

# %% [markdown]
# ## 1. BOW

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
bow = CountVectorizer()

# %% [markdown]
# Fit transform on the keywords

# %%
X
# Out:
# 0     tg biodiesel application traditional analysis ...
# 1     domain ftp control snmp cyclic window digital ...
# 2     domain 3nf deleting control shadow failure par...
# 3     extended pigeonhole eulerian inverse shortest ...
# 4     case finding order major algorithm notation in...
# 5     k composition kinematics velocity applicable a...
# 6     ambiguity io algorithm introduction access var...
# 7     reference consumer fifo partitioning algorithm...
# 8     uncertain application mycin set machine minima...
# 9     modeling j ecos read analytics theorem circula...
# 10    qualitative modeling implementation discretiza...
# 11    node express php xml mern jquery react j ajax ...
# 12    administrative cia anonymizers control symmetr...
# 13    sop combinational computer key binary applicat...
# 14    stage task cache branch pipelining handling sf...
# 15    queue direct trie b traversal perfect dikjtras...
# 16    encoding direct recursive counter mathematical...
# 17    exponential testing poisson f statistic theore...
# 18    testing modeling verification user chain ssad ...
# Name: extracted_keywords, dtype: object

# %%
vectors = bow.fit_transform(X).toarray()

# %% [markdown]
# Next, transform on the video keywords

# %%
yt['combo'][0]
# Out:
# 'serhiy first agustn website start extraction web agent conclusion proxy course header jedi joe wcislo deploying part maneerat run crawling introduction step plan fake doc user scheduling learn github comparison kalinets cleaning database hundred resource smartproxy project scrapy build scheduler monitor file python setup developer justin job thanks data free programming sith code read mysql scraping aggregator cloud bannedkussrow csv morgan next virtual postgres supporter pipeline scraper beginner get tool guide getting scrapyd hual environmentsenv avoid playbook browser article item resourcessponsor davthecoder nattira apis teach proxiesdiscovery rotating champion kearney scrapydweb databasesneed scrapycreating saving heather scale blockedcreated content scrapeops spider usingotis spiderpipelines'

# %%
yt['title'][0]
# Out:
# 'scrapy course – python web scraping for beginners'

# %%
video_vector = bow.transform([yt['title'][0]])

# %%
video_vector
# Out:
# <1x1329 sparse matrix of type '<class 'numpy.int64'>'
# 	with 0 stored elements in Compressed Sparse Row format>

# %%
video_vector.toarray()
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]], dtype=int64)

# %%
video_vectors = bow.transform(yt['title'])

# %%
vectors.shape
# Out:
# (19, 1329)

# %%
video_vector.shape
# Out:
# (1, 1329)

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(random_state=42)

# %%
y.shape
# Out:
# (19,)

# %%
rf.fit(vectors, y)
# Out:
# RandomForestClassifier(random_state=42)

# %%
all_videos = bow.transform(yt['combo'])

# %%
pred = rf.predict(all_videos)

# %%
pred
# Out:
# array(['fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'daa', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'bdt', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'bdt', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd'], dtype=object)

# %% [markdown]
# ### Multinomial Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer

# %%
nb = Pipeline([('vect', CountVectorizer()),
               ('tfidf', TfidfTransformer()),
               ('clf', MultinomialNB()),
              ])

# %%
nb.fit(X, y)
# Out:
# Pipeline(steps=[('vect', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('clf', MultinomialNB())])

# %%
model = MultinomialNB().fit(vectors,y)

# %%
yt['combo_processed'][5]
# Out:
# 'c language tutorial beginner join new web development batch using link delta 3 0 early bird offer first 5000 student international student detail delta 3 0 batch start date 7th november 2023 alternate day lecture duration 4 5 month class duration 1 5 hour 2hour access course 2 year complete frontend development html cs javascript reactjs complete backend development complete database complete mern stack real life industry grade project live mentorship session 500 topic video certificate given completion join community code note practice sheet timestamps introduction 00 00 00installation 00 01 27compiler setup 00 04 31chapter 1 variable data type input output 00 10 12chapter 2 instruction operator 00 51 54chapter 3 conditional statement 02 01 15chapter 4 loop control statement 02 45 36 chapter 5 function recursion 03 51 34chapter 6 pointer 05 21 30chapter 7 array 06 18 50chapter 8 string 07 22 29chapter 9 structure 08 26 20chapter 10 file 09 22 15chapter 11 dynamic memory allocation 10 05 00java placement course complete c placement course instagram'

# %%
tfidf.transform(['html'])
# Out:
# <1x1341 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>

# %% [markdown]
# synchronousunit division function

# %%
model.predict(tfidf.transform(['synchronousunit division function']))
# Out:
# array(['oop'], dtype='<U4')

# %%
yt['title'][1]
# Out:
# 'scrapy for beginners - a complete how to example web scraping project'

# %%
nb.predict(yt['title'])
# Out:
# array(['ads', 'daa', 'bdt', 'dmgt', 'ads', 'aies', 'oop', 'aies', 'aies',
#        'aies', 'bdt', 'fds', 'ads', 'oop', 'fds', 'sepm', 'ddca', 'sepm',
#        'fds', 'daa', 'daa', 'daa', 'ads', 'bdt', 'ads', 'ads', 'ads',
#        'ads', 'ads', 'ads', 'fds', 'fds', 'fds', 'oop', 'fds', 'ads',
#        'fds', 'ads', 'ads', 'fds', 'os', 'os', 'os', 'os', 'os', 'os',
#        'os', 'os', 'os', 'os', 'os', 'os', 'os', 'os', 'os', 'ads', 'mmc',
#        'os', 'os', 'os', 'daa', 'daa', 'de', 'fds', 'ddca', 'oop', 'oop',
#        'oop', 'oop', 'oop', 'de', 'mech', 'de', 'de', 'de', 'mech', 'ads',
#        'mech', 'mech', 'de', 'de', 'dmgt', 'dmgt', 'dmgt', 'dmgt', 'oop',
#        'dmgt', 'ads', 'dmgt', 'aies', 'mmc', 'dmgt', 'dmgt', 'dmgt',
#        'ics', 'dmgt', 'ads', 'dmgt', 'ads', 'dmgt', 'mmc', 'os', 'os',
#        'mmc', 'mmc', 'mmc', 'mmc', 'mmc', 'mmc', 'mmc', 'ads', 'os',
#        'oop', 'mmc', 'os', 'os', 'os', 'os', 'fds', 'os', 'os', 'os',
#        'os', 'daa', 'ps', 'os', 'os', 'os', 'os', 'os', 'os', 'os', 'os',
#        'os', 'os', 'dbms', 'de', 'mmc', 'dbms', 'dbms', 'dbms', 'dbms',
#        'bdt', 'dbms', 'dbms', 'dbms', 'ads', 'dbms', 'dbms', 'dbms',
#        'dbms', 'dbms', 'dbms', 'dbms', 'dbms', 'dbms', 'dbms', 'dbms',
#        'dbms', 'dbms', 'bdt', 'dbms', 'bdt', 'ads', 'dbms', 'dbms',
#        'dbms', 'dbms', 'dbms', 'dbms', 'fds', 'fds', 'fds', 'fds', 'fds',
#        'fds', 'fds', 'fds', 'fds', 'fds', 'daa', 'oop', 'fds', 'daa',
#        'daa', 'fds', 'fds', 'fds', 'fds', 'fds', 'fds', 'fds', 'fds',
#        'fds', 'ads', 'fds', 'ads', 'ads', 'ads', 'fds', 'fds', 'fds',
#        'fds', 'fds', 'fds', 'ddca', 'ddca', 'ddca', 'sepm', 'ads', 'ddca',
#        'ads', 'cn', 'ads', 'ads', 'mmc', 'mmc', 'mmc', 'mmc', 'os',
#        'ddca', 'ddca', 'ddca', 'ddca', 'ddca', 'ddca', 'ddca', 'ddca',
#        'ddca', 'ddca', 'os', 'os', 'os', 'mmc', 'os', 'ics', 'ics', 'ics',
#        'oop', 'ics', 'ics', 'ics', 'ics', 'ics', 'ics', 'ics', 'ics',
#        'ics', 'ics', 'ics', 'ics', 'dmgt', 'ics', 'dmgt', 'ics', 'dmgt',
#        'dmgt', 'dmgt', 'ics', 'dmgt', 'dmgt', 'dmgt', 'dmgt', 'dmgt',
#        'dmgt', 'oop', 'ics', 'ics', 'fds', 'ics', 'ps', 'de', 'de',
#        'aies', 'de', 'de', 'de', 'de', 'de', 'de', 'dmgt', 'dmgt', 'de',
#        'de', 'dmgt', 'dmgt', 'dmgt', 'de', 'de', 'ps', 'de', 'de', 'de',
#        'de', 'de', 'de', 'de', 'de', 'de', 'de', 'de', 'aies', 'de', 'de',
#        'sepm', 'ps', 'de', 'ps', 'sepm', 'de', 'de', 'de', 'de', 'de',
#        'de', 'de', 'de', 'de', 'oop', 'de', 'de', 'fds', 'de', 'de', 'de',
#        'de', 'de', 'de', 'de', 'de', 'de', 'de', 'de', 'de', 'aies', 'os',
#        'de', 'de', 'bdt', 'de', 'de', 'aies', 'os', 'de', 'de', 'dmgt',
#        'dmgt', 'dmgt', 'dmgt', 'daa', 'bdt', 'bdt', 'bdt', 'bdt', 'bdt',
#        'ddca', 'bdt', 'bdt', 'dbms', 'bdt', 'bdt', 'bdt', 'fsd', 'bdt',
#        'bdt', 'fsd', 'bdt', 'bdt', 'bdt', 'bdt', 'bdt', 'bdt', 'bdt',
#        'bdt', 'bdt', 'bdt', 'bdt', 'bdt', 'bdt', 'bdt', 'bdt', 'bdt',
#        'bdt', 'bdt', 'bdt', 'bdt', 'fds', 'bdt', 'bdt', 'bdt', 'bdt',
#        'bdt', 'de', 'ads', 'bdt', 'bdt', 'bdt', 'bdt', 'oop', 'bdt',
#        'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies',
#        'ads', 'oop', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies',
#        'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies',
#        'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies',
#        'aies', 'aies', 'aies', 'aies', 'ps', 'ps', 'aies', 'ps', 'aies',
#        'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies',
#        'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies',
#        'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies',
#        'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies',
#        'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'os',
#        'aies', 'aies', 'aies', 'aies', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'daa', 'fsd', 'ads', 'ads', 'ads', 'ads', 'ads', 'cn', 'ics',
#        'ads', 'ads', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'bdt', 'fsd',
#        'bdt', 'bdt', 'bdt', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'ads', 'ads', 'oop', 'oop',
#        'aies', 'dmgt', 'oop', 'dmgt', 'oop', 'oop', 'oop', 'oop', 'oop',
#        'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop',
#        'oop', 'oop', 'oop', 'ads', 'oop', 'ads', 'oop', 'oop', 'oop',
#        'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop',
#        'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop',
#        'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop',
#        'oop', 'oop'], dtype='<U4')

# %%
model.fit(vectors, y)
# Out:
# MultinomialNB()

# %%
model.predict(video_vector)
# Out:
# array(['os'], dtype='<U4')

# %%
yt['title'][1]
# Out:
# 'scrapy for beginners - a complete how to example web scraping project'

# %%
model.predict(video_vectors)
# Out:
# array(['ads', 'oop', 'bdt', 'dmgt', 'ads', 'aies', 'oop', 'aies', 'aies',
#        'aies', 'ddca', 'fds', 'ads', 'oop', 'fds', 'sepm', 'ddca', 'sepm',
#        'fds', 'daa', 'daa', 'bdt', 'ads', 'bdt', 'ads', 'ads', 'mmc',
#        'mmc', 'mmc', 'fds', 'fds', 'fds', 'fds', 'oop', 'fds', 'ads',
#        'fds', 'oop', 'ads', 'fds', 'os', 'os', 'os', 'os', 'os', 'os',
#        'os', 'os', 'os', 'os', 'os', 'os', 'os', 'os', 'os', 'ads', 'mmc',
#        'os', 'os', 'os', 'daa', 'daa', 'de', 'fds', 'oop', 'oop', 'oop',
#        'oop', 'oop', 'oop', 'de', 'mech', 'de', 'de', 'de', 'mech', 'ads',
#        'mech', 'mech', 'de', 'de', 'dmgt', 'dmgt', 'dmgt', 'dmgt', 'oop',
#        'dmgt', 'ads', 'dmgt', 'aies', 'mmc', 'dmgt', 'dmgt', 'dmgt',
#        'sepm', 'dmgt', 'ads', 'dmgt', 'ads', 'dmgt', 'mmc', 'os', 'os',
#        'mmc', 'mmc', 'mmc', 'mmc', 'mmc', 'mmc', 'mmc', 'mmc', 'os',
#        'oop', 'mmc', 'mmc', 'os', 'os', 'os', 'fds', 'os', 'os', 'os',
#        'os', 'daa', 'daa', 'os', 'os', 'os', 'os', 'os', 'os', 'os', 'os',
#        'os', 'os', 'sepm', 'ps', 'dmgt', 'dbms', 'dbms', 'dbms', 'dbms',
#        'bdt', 'dbms', 'dbms', 'dbms', 'ads', 'dbms', 'dbms', 'dbms',
#        'dbms', 'dbms', 'dbms', 'dbms', 'dbms', 'dbms', 'dbms', 'dbms',
#        'dbms', 'dbms', 'bdt', 'dbms', 'bdt', 'ads', 'oop', 'dbms', 'dbms',
#        'dbms', 'dbms', 'dbms', 'fds', 'fds', 'fds', 'fds', 'fds', 'fds',
#        'fds', 'fds', 'fds', 'fds', 'daa', 'oop', 'fds', 'daa', 'daa',
#        'fds', 'fds', 'fds', 'fds', 'fds', 'fds', 'fds', 'fds', 'fds',
#        'ads', 'fds', 'ads', 'ads', 'fds', 'fds', 'fds', 'fds', 'fds',
#        'fds', 'fds', 'ddca', 'ddca', 'ddca', 'sepm', 'ads', 'ddca', 'ads',
#        'cn', 'ads', 'ads', 'mmc', 'mmc', 'mmc', 'mmc', 'os', 'ddca',
#        'ddca', 'ddca', 'ddca', 'ddca', 'ddca', 'ddca', 'ddca', 'ddca',
#        'ddca', 'os', 'os', 'os', 'mmc', 'os', 'ics', 'ics', 'ics', 'oop',
#        'ics', 'ics', 'ics', 'ics', 'ics', 'ics', 'ics', 'ics', 'ics',
#        'ics', 'ics', 'ics', 'dmgt', 'ics', 'dmgt', 'ics', 'ics', 'dmgt',
#        'dmgt', 'ics', 'dmgt', 'dmgt', 'dmgt', 'dmgt', 'dmgt', 'dmgt',
#        'oop', 'ics', 'ics', 'os', 'ics', 'ps', 'cn', 'de', 'ps', 'de',
#        'de', 'de', 'de', 'de', 'de', 'dmgt', 'oop', 'de', 'de', 'de',
#        'dmgt', 'oop', 'de', 'de', 'ps', 'oop', 'de', 'de', 'de', 'de',
#        'oop', 'de', 'de', 'de', 'de', 'de', 'ddca', 'de', 'de', 'sepm',
#        'ps', 'de', 'ps', 'sepm', 'fds', 'de', 'de', 'de', 'de', 'bdt',
#        'de', 'de', 'de', 'oop', 'de', 'ddca', 'fds', 'de', 'de', 'de',
#        'de', 'de', 'de', 'de', 'de', 'oop', 'de', 'de', 'de', 'aies',
#        'ps', 'de', 'aies', 'bdt', 'de', 'oop', 'aies', 'os', 'oop', 'de',
#        'dmgt', 'dmgt', 'dmgt', 'dmgt', 'daa', 'bdt', 'bdt', 'bdt', 'bdt',
#        'bdt', 'ddca', 'bdt', 'bdt', 'ddca', 'bdt', 'bdt', 'bdt', 'bdt',
#        'bdt', 'bdt', 'bdt', 'bdt', 'bdt', 'bdt', 'bdt', 'bdt', 'bdt',
#        'bdt', 'bdt', 'bdt', 'bdt', 'bdt', 'bdt', 'bdt', 'bdt', 'bdt',
#        'bdt', 'bdt', 'bdt', 'bdt', 'bdt', 'fds', 'bdt', 'bdt', 'bdt',
#        'bdt', 'bdt', 'de', 'ads', 'bdt', 'bdt', 'bdt', 'bdt', 'oop',
#        'bdt', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies',
#        'aies', 'oop', 'oop', 'aies', 'aies', 'aies', 'aies', 'aies',
#        'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies',
#        'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies',
#        'aies', 'aies', 'aies', 'aies', 'ps', 'ps', 'ps', 'aies', 'ps',
#        'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies',
#        'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies',
#        'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies',
#        'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies',
#        'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies', 'aies',
#        'os', 'aies', 'aies', 'aies', 'aies', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'daa', 'fsd', 'ads', 'ads', 'ads', 'ads', 'ads', 'cn',
#        'ics', 'ads', 'ads', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'bdt',
#        'fsd', 'bdt', 'bdt', 'bdt', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'aies', 'fsd', 'fsd', 'fsd', 'fsd',
#        'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'fsd', 'ads', 'ads', 'oop',
#        'oop', 'aies', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop',
#        'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop',
#        'oop', 'oop', 'oop', 'oop', 'ads', 'oop', 'ads', 'oop', 'oop',
#        'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop',
#        'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop',
#        'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop', 'oop',
#        'oop', 'oop', 'oop'], dtype='<U4')

# %% [markdown]
# ### Catboost Classifier

# %%
from catboost import CatBoostClassifier

# %%
cb = CatBoostClassifier(iterations=100, depth=6, learning_rate=0.1, loss_function='MultiClass')

# %%
X

# %%
y

# %%
cb.fit(vectors, y)

# %%
video_vectors.shape

# %%
video_vector.shape

# %%
pred = cb.predict(video_vectors)

# %%
pd.DataFrame(pred).value_counts()

# %% [markdown]
# - Used TF-IDF, fit_transform on the keywords --> vectorizer
# - Used vectorizer's transform on the video title+desc --> video_vectors
# - model.fit(video_vectors, labels) --> labels are the subjects
# - new_video_vector = vectorizer.transform(new_video)
# - subject_prediction = model.predict(new_video_vector)

# %% [markdown]
# ## 2. TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer()

# %%
vectors = tfidf.fit_transform(X).toarray()

# %%
tfidf.get_feature_names_out()[:50]

# %%
pd.DataFrame(vectors, columns=tfidf.get_feature_names_out())

# %%
vectors

# %%
video_vector = tfidf.transform([yt['combo'][0]])

# %%
video_vectors = tfidf.transform(yt['combo'])

# %%
rf.fit(vectors, y)

# %%
pred = rf.predict(video_vectors)

# %%
pred

# %% [markdown]
# ## 3. N-Grams

# %%
ng = CountVectorizer(ngram_range=(1, 3))

# %%
vectors = ng.fit_transform(X).toarray()

# %%
video_vector = ng.transform([yt['combo'][0]])

# %%
rf.fit(vectors, y)

# %%
rf.predict(video_vector)
